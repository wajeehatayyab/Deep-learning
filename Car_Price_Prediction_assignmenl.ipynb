# %% [markdown]
# <a href="https://colab.research.google.com/github/wajeehatayyab/Deep-learning/blob/main/Car_Price_Prediction_assignmenl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # **Problem Statement::**

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task:
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # **WorkFlow**

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
cd /content/drive/MyDrive/Deeplearning_Assignment /
# Out:
# /content/drive/MyDrive/Deeplearning_Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
car_data = pd.read_csv('/content/drive/MyDrive/Deeplearning_Assignment /CarPrice_Assignment.csv')

# %%
car_data.head(10)
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg      price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.000
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.000
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.000
# 3       4          2               audi 100 ls  ...      24         30  13950.000
# 4       5          2                audi 100ls  ...      18         22  17450.000
# 5       6          2                  audi fox  ...      19         25  15250.000
# 6       7          1                audi 100ls  ...      19         25  17710.000
# 7       8          1                 audi 5000  ...      19         25  18920.000
# 8       9          1                 audi 4000  ...      17         20  23875.000
# 9      10          0       audi 5000s (diesel)  ...      16         22  17859.167
#
# [10 rows x 26 columns]

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 128)               24704
# _________________________________________________________________
# dense_97 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_98 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 128)               24704
# _________________________________________________________________
# dense_101 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_102 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_104 (Dense)            (None, 10)                1930
# _________________________________________________________________
# dense_105 (Dense)            (None, 8)                 88
# _________________________________________________________________
# dense_106 (Dense)            (None, 6)                 54
# _________________________________________________________________
# dense_107 (Dense)            (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_108 (Dense)            (None, 10)                1930
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_109 (Dense)            (None, 8)                 88
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_110 (Dense)            (None, 6)                 54
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b1896f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55af3bd3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55aad95680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55aad95320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b1896d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b3c66cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b4d1d7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b86b03b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b9039950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55a9bae560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55bde3a830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55af3c4b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8604 - mae: 0.7133
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6592 - mae: 0.5800
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8837 - mae: 0.6057
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5487 - mae: 0.4259
# Epoch 5/100
# 106/106 [==============================] - 0s 999us/step - loss: 0.4986 - mae: 0.5045
# Epoch 6/100
# 106/106 [==============================] - 0s 895us/step - loss: 0.2559 - mae: 0.3683
# Epoch 7/100
# 106/106 [==============================] - 0s 933us/step - loss: 0.3059 - mae: 0.3789
# Epoch 8/100
# 106/106 [==============================] - 0s 876us/step - loss: 0.3792 - mae: 0.4094
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2349 - mae: 0.3709
# Epoch 10/100
# 106/106 [==============================] - 0s 923us/step - loss: 0.3477 - mae: 0.3687
# Epoch 11/100
# 106/106 [==============================] - 0s 907us/step - loss: 0.4776 - mae: 0.4143
# Epoch 12/100
# 106/106 [==============================] - 0s 946us/step - loss: 0.3204 - mae: 0.3936
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1795 - mae: 0.3151
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5501 - mae: 0.4486
# Epoch 15/100
# 106/106 [==============================] - 0s 952us/step - loss: 0.2413 - mae: 0.3637
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2493 - mae: 0.3441
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1833 - mae: 0.3107
# Epoch 18/100
# 106/106 [==============================] - 0s 917us/step - loss: 0.1541 - mae: 0.2969
# Epoch 19/100
# 106/106 [==============================] - 0s 942us/step - loss: 0.4957 - mae: 0.3962
# Epoch 20/100
# 106/106 [==============================] - 0s 938us/step - loss: 0.2423 - mae: 0.3550
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2579 - mae: 0.3724
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2917 - mae: 0.3587
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3692 - mae: 0.3844
# Epoch 24/100
# 106/106 [==============================] - 0s 982us/step - loss: 0.1832 - mae: 0.2926
# Epoch 25/100
# 106/106 [==============================] - 0s 985us/step - loss: 0.2033 - mae: 0.3269
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4194 - mae: 0.3643
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3446 - mae: 0.3520
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3966 - mae: 0.4097
# Epoch 29/100
# 106/106 [==============================] - 0s 998us/step - loss: 0.3445 - mae: 0.4221
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3191 - mae: 0.3278
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2049 - mae: 0.2860
# Epoch 32/100
# 106/106 [==============================] - 0s 950us/step - loss: 0.2437 - mae: 0.3112
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2250 - mae: 0.3199
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2332 - mae: 0.3146
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2163 - mae: 0.2912
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3412 - mae: 0.3041
# Epoch 37/100
# 106/106 [==============================] - 0s 939us/step - loss: 0.5141 - mae: 0.3648
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4022 - mae: 0.3739
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1564 - mae: 0.2620
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0929 - mae: 0.2220
# Epoch 41/100
# 106/106 [==============================] - 0s 959us/step - loss: 0.2004 - mae: 0.2443
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4251 - mae: 0.3354
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.2695
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1418 - mae: 0.2510
# Epoch 45/100
# 106/106 [==============================] - 0s 952us/step - loss: 0.4364 - mae: 0.4003
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1972 - mae: 0.2508
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3435 - mae: 0.3768
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1338 - mae: 0.2336
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2584 - mae: 0.3366
# Epoch 50/100
# 106/106 [==============================] - 0s 952us/step - loss: 0.1918 - mae: 0.3148
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1782 - mae: 0.2819
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2541 - mae: 0.3238
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2386 - mae: 0.3106
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1771 - mae: 0.2358
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1431 - mae: 0.2378
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1474 - mae: 0.2571
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3243 - mae: 0.3786
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2239 - mae: 0.3177
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1804 - mae: 0.2773
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3047 - mae: 0.3028
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1793 - mae: 0.2479
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3859 - mae: 0.3294
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1757 - mae: 0.2460
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3379 - mae: 0.3694
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1041 - mae: 0.2145
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1087 - mae: 0.2235
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2655 - mae: 0.2881
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3133 - mae: 0.3171
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4004 - mae: 0.3478
# Epoch 70/100
# 106/106 [==============================] - 0s 988us/step - loss: 0.1598 - mae: 0.2528
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3621 - mae: 0.3823
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3853 - mae: 0.3431
# Epoch 73/100
# 106/106 [==============================] - 0s 988us/step - loss: 0.2074 - mae: 0.2684
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3221 - mae: 0.3118
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2079 - mae: 0.2958
# Epoch 76/100
# 106/106 [==============================] - 0s 980us/step - loss: 0.1895 - mae: 0.2472
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2522 - mae: 0.3105
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2381 - mae: 0.2844
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2196 - mae: 0.2713
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1122 - mae: 0.2361
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2649 - mae: 0.3047
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2936 - mae: 0.2991
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1078 - mae: 0.2189
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3218 - mae: 0.3225
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1808 - mae: 0.2665
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1039 - mae: 0.2076
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2181 - mae: 0.2822
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2128 - mae: 0.2736
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1372 - mae: 0.2430
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1822 - mae: 0.2995
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2821 - mae: 0.2883
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1300 - mae: 0.2235
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5344 - mae: 0.3255
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2438 - mae: 0.2813
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3100 - mae: 0.3230
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3508 - mae: 0.3303
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4207 - mae: 0.3146
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2758 - mae: 0.3092
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1604 - mae: 0.2497
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2393 - mae: 0.2841
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b4d6b050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4366 - mae: 0.4149
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.6294 - mae: 0.5718
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3754 - mae: 0.4304
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6451 - mae: 0.5005
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5326 - mae: 0.4877
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5487 - mae: 0.5032
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5016 - mae: 0.4886
# Epoch 7/100
# 106/106 [==============================] - 0s 956us/step - loss: 0.5050 - mae: 0.5403
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4718 - mae: 0.4387
# Epoch 9/100
# 106/106 [==============================] - 0s 999us/step - loss: 0.6486 - mae: 0.4747
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2917 - mae: 0.3410
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3209 - mae: 0.3583
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3944 - mae: 0.4431
# Epoch 13/100
# 106/106 [==============================] - 0s 995us/step - loss: 0.5257 - mae: 0.4766
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4097 - mae: 0.4221
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6017 - mae: 0.4886
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2844 - mae: 0.3702
# Epoch 17/100
# 106/106 [==============================] - 0s 954us/step - loss: 0.3654 - mae: 0.3568
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4684 - mae: 0.4583
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5775 - mae: 0.4278
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4147 - mae: 0.3636
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2472 - mae: 0.3535
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2563 - mae: 0.3580
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4871 - mae: 0.4174
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3553 - mae: 0.4120
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4443 - mae: 0.4900
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2385 - mae: 0.3357
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3636 - mae: 0.3518
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3789 - mae: 0.3854
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3811 - mae: 0.3695
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2957 - mae: 0.3661
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2063 - mae: 0.2935
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7089 - mae: 0.4276
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5411 - mae: 0.4107
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2111 - mae: 0.2952
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2180 - mae: 0.3117
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5252 - mae: 0.4866
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2652 - mae: 0.3419
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1859 - mae: 0.2778
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2976 - mae: 0.4010
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2472 - mae: 0.3486
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3590 - mae: 0.3884
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2893 - mae: 0.3629
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3194 - mae: 0.3306
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2445 - mae: 0.3212
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2677 - mae: 0.2984
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2177 - mae: 0.2991
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1794 - mae: 0.3074
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1853 - mae: 0.2819
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1948 - mae: 0.3115
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2014 - mae: 0.2701
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3395 - mae: 0.3570
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4016 - mae: 0.3729
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1944 - mae: 0.2905
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2900 - mae: 0.3171
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1399 - mae: 0.2713
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2874 - mae: 0.3305
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1459 - mae: 0.2651
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3505 - mae: 0.3483
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1634 - mae: 0.2747
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1735 - mae: 0.2710
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1555 - mae: 0.2857
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1680 - mae: 0.2726
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1776 - mae: 0.2630
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4068 - mae: 0.3543
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2051 - mae: 0.3050
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2135 - mae: 0.3123
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1490 - mae: 0.2683
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1218 - mae: 0.2704
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2739 - mae: 0.3533
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2505 - mae: 0.3443
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1300 - mae: 0.2692
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1783 - mae: 0.2729
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3360 - mae: 0.3341
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2682 - mae: 0.3296
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1101 - mae: 0.2351
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2067 - mae: 0.2848
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2382 - mae: 0.2862
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1577 - mae: 0.2702
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2297 - mae: 0.2823
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2691 - mae: 0.2873
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3317 - mae: 0.3351
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3592 - mae: 0.3612
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1380 - mae: 0.2464
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2086 - mae: 0.2816
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2087 - mae: 0.2936
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2960 - mae: 0.2905
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2597 - mae: 0.3151
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1685 - mae: 0.2520
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2882 - mae: 0.3004
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2447 - mae: 0.2998
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1851 - mae: 0.2874
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2196 - mae: 0.2991
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1830 - mae: 0.2956
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2622 - mae: 0.3218
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1871 - mae: 0.2995
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3924 - mae: 0.3207
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2312 - mae: 0.3159
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2778 - mae: 0.3329
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3553 - mae: 0.3173
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1720 - mae: 0.2372
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55aad6bf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7629 - mae: 0.5697
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2351 - mae: 0.7116
# Epoch 2/100
# 106/106 [==============================] - 0s 947us/step - loss: 0.8457 - mae: 0.6228
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0619 - mae: 0.6305
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7778 - mae: 0.5759
# Epoch 5/100
# 106/106 [==============================] - 0s 985us/step - loss: 0.9411 - mae: 0.6408
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7732 - mae: 0.5642
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6740 - mae: 0.5335
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6659 - mae: 0.5510
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5266 - mae: 0.4365
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7543 - mae: 0.5234
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6300 - mae: 0.4780
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5545 - mae: 0.4916
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0777 - mae: 0.6557
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6397 - mae: 0.4695
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9808 - mae: 0.5741
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8216 - mae: 0.5303
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5686 - mae: 0.4736
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7651 - mae: 0.5523
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4913 - mae: 0.4452
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5345 - mae: 0.4520
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3585 - mae: 0.3433
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5798 - mae: 0.4872
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6950 - mae: 0.4819
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7547 - mae: 0.5645
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8748 - mae: 0.5403
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6885 - mae: 0.4793
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5314 - mae: 0.4842
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6828 - mae: 0.4947
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6201 - mae: 0.5087
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8307 - mae: 0.6182
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0022 - mae: 0.6559
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5955 - mae: 0.4289
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5118 - mae: 0.4279
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7829 - mae: 0.5803
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5542 - mae: 0.4501
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4544 - mae: 0.4282
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4958 - mae: 0.4573
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5460 - mae: 0.4826
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5802 - mae: 0.4591
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5116 - mae: 0.4576
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4598 - mae: 0.4174
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3678 - mae: 0.3523
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4749 - mae: 0.4356
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4139 - mae: 0.4026
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4737 - mae: 0.4188
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6898 - mae: 0.5651
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5702 - mae: 0.4855
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5139 - mae: 0.4576
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3096 - mae: 0.3839
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6195 - mae: 0.5162
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3924 - mae: 0.4206
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4718 - mae: 0.4427
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4806 - mae: 0.4796
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6856 - mae: 0.5216
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7334 - mae: 0.5325
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1162 - mae: 0.7077
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6461 - mae: 0.5536
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5779 - mae: 0.4998
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4780 - mae: 0.4506
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4377 - mae: 0.4163
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4499 - mae: 0.4474
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6138 - mae: 0.4971
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6726 - mae: 0.5220
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7440 - mae: 0.5830
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6482 - mae: 0.5531
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6971 - mae: 0.4954
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3060 - mae: 0.3468
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6364 - mae: 0.5641
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5590 - mae: 0.4721
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5041 - mae: 0.4195
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6714 - mae: 0.5482
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4300 - mae: 0.4245
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5967 - mae: 0.4915
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5049 - mae: 0.4902
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5544 - mae: 0.5135
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5178 - mae: 0.5024
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5734 - mae: 0.5320
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3385 - mae: 0.4075
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5950 - mae: 0.4806
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5363 - mae: 0.5191
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4905 - mae: 0.4875
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5257 - mae: 0.4838
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6778 - mae: 0.5515
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3935 - mae: 0.4072
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4279 - mae: 0.4369
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7033 - mae: 0.5475
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4551 - mae: 0.4376
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4351 - mae: 0.4831
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4696 - mae: 0.4377
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4882 - mae: 0.4696
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5625 - mae: 0.5384
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3378 - mae: 0.3793
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4031 - mae: 0.4395
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5682 - mae: 0.4974
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7139 - mae: 0.5565
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2661 - mae: 0.3515
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4548 - mae: 0.4613
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3377 - mae: 0.3780
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6748 - mae: 0.5625
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4718 - mae: 0.4759
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55aac4a290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5141 - mae: 0.5915
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.7964 - mae: 0.6795
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6677 - mae: 0.5238
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7944 - mae: 0.6492
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7268 - mae: 0.5853
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7369 - mae: 0.5975
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4472 - mae: 0.4985
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3314 - mae: 0.4344
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4988 - mae: 0.4843
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5915 - mae: 0.4605
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4236 - mae: 0.4704
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4587 - mae: 0.4574
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3580 - mae: 0.3984
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5707 - mae: 0.4716
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2999 - mae: 0.3784
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4907 - mae: 0.4420
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3429 - mae: 0.3717
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3219 - mae: 0.3930
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4027 - mae: 0.4134
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3622 - mae: 0.3969
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4272 - mae: 0.3858
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4083 - mae: 0.4263
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4613 - mae: 0.4320
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2999 - mae: 0.3462
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1592 - mae: 0.2974
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5040 - mae: 0.5060
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3980 - mae: 0.4044
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6380 - mae: 0.5084
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1638 - mae: 0.2913
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4808 - mae: 0.4299
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2391 - mae: 0.3545
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7363 - mae: 0.5664
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2499 - mae: 0.3359
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5349 - mae: 0.4206
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1867 - mae: 0.3180
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4117 - mae: 0.3933
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2394 - mae: 0.3827
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2192 - mae: 0.3394
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2456 - mae: 0.3654
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1646 - mae: 0.2695
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3494 - mae: 0.3741
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1760 - mae: 0.3266
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2353 - mae: 0.3586
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5704 - mae: 0.4528
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3145 - mae: 0.3944
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3248 - mae: 0.3657
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1491 - mae: 0.2679
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2349 - mae: 0.3359
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2470 - mae: 0.3494
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2155 - mae: 0.3398
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3069 - mae: 0.3641
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6050 - mae: 0.4670
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1498 - mae: 0.2712
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3292 - mae: 0.3956
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3201 - mae: 0.3627
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2371 - mae: 0.3486
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3085 - mae: 0.3311
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1763 - mae: 0.3145
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1816 - mae: 0.3136
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5076 - mae: 0.4484
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1444 - mae: 0.2872
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2589 - mae: 0.3330
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3664 - mae: 0.3691
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2822 - mae: 0.3538
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4143 - mae: 0.3995
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3595 - mae: 0.3380
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3323 - mae: 0.3283
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2396 - mae: 0.3147
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3060 - mae: 0.3629
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2069 - mae: 0.3028
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5388 - mae: 0.3869
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2417 - mae: 0.3678
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3225 - mae: 0.3831
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2104 - mae: 0.3582
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2075 - mae: 0.2831
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2328 - mae: 0.3266
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1647 - mae: 0.2648
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1833 - mae: 0.3006
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2372 - mae: 0.3248
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2695 - mae: 0.3353
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1226 - mae: 0.2713
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1914 - mae: 0.2813
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1900 - mae: 0.2695
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2091 - mae: 0.3214
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1965 - mae: 0.3020
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2958 - mae: 0.3228
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1920 - mae: 0.3128
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1815 - mae: 0.3048
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1689 - mae: 0.2702
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2759 - mae: 0.3311
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2013 - mae: 0.2925
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2193 - mae: 0.3300
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2746 - mae: 0.3577
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3180 - mae: 0.3787
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2482 - mae: 0.3307
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1893 - mae: 0.3254
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1328 - mae: 0.2815
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2433 - mae: 0.3331
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2969 - mae: 0.3871
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2513 - mae: 0.3286
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2077 - mae: 0.2975
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b3b360e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1702 - mae: 0.2757

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.34972676634788513,
#  0.34343311190605164,
#  0.33903199434280396,
#  0.2898084223270416]

# %%
all_scores_tanh
# Out:
# [0.27205511927604675,
#  0.3604274392127991,
#  0.30197250843048096,
#  0.3152778148651123]

# %%
all_scores_regular
# Out:
# [0.28565123677253723,
#  0.28593483567237854,
#  0.333400696516037,
#  0.37920352816581726]

# %%
all_scores_drop
# Out:
# [0.4148973226547241,
#  0.5697472095489502,
#  0.5915379524230957,
#  0.27571746706962585]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b44a28c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0899 - mae: 0.2368

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b6831170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0683 - mae: 0.2043

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b1896b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1378 - mae: 0.2391

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f55b1896290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1502 - mae: 0.2836

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55b44a20e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ' the predicted Price was : [[20714.219]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55bdadcdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ' the predicted Price was : [[21521.348]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55a9bae8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ' the predicted Price was : [[22547.23]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# WARNING:tensorflow:8 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55a9bae4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ' the predicted Price was : [[19609.143]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55bdadcdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55b44a20e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55a9bae8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55a9bae4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
